# %%
import pandas as pd
import numpy as np

# %%
file = "./sample_bank_statement.csv"
df = pd.read_csv(file)

# %%
df.head()

# %%
df.describe

# %%
unique=df["Status"].unique

# %%
df["Date"] = pd.to_datetime(df["Date"])
df.set_index("Date", inplace=True)

# %%
df.head()

# %% [markdown]
# # Data Cleaning

# %%
df["Amount"] = df["Amount"].str.replace(",", "", regex = False)
df.head()

# %%
df = df.drop("Unnamed: 6", axis = 1)
df.head()
